# %%
import numpy as np
import pandas as pd
import json
import statistics
import matplotlib.pyplot as plt
# %matplotlib inline
from openpyxl import workbook
from openpyxl.utils.dataframe import dataframe_to_rows

# %% [markdown]
# 1# Analise de Jogos de corrida usando Steam Spy. Realizamos a extração dos dados via código com api steam, definida tag 'racing'.

# %%
df_games = pd.read_json(r'E:\data_analisys\games.json')

# %%
df_games.head(45)
# Out:
#                                                                     606850   \
# name                                                             VR Batting
# release_date                                                   Mar 20, 2017
# required_age                                                              0
# price                                                                  9.99
# dlc_count                                                                 0
# detailed_description      'VR Batting' is a virtual reality cricket simu...
# about_the_game            'VR Batting' is a virtual reality cricket simu...
# short_description         'VR Batting' is a virtual reality cricket simu...
# reviews
# header_image              https://cdn.akamai.steamstatic.com/steam/apps/...
# website
# support_url                                                www.arbisoft.com
# support_email                                        saad.khan@arbisoft.com
# ...

# %% [markdown]
# 2# Fazendo a transposta pelo numpy

# %%
df_games.T
# Out:
#                                  name  release_date required_age  price  \
# 606850                     VR Batting  Mar 20, 2017            0   9.99
# 1787030                 Safari Cannon  Oct 28, 2021            0   2.99
# 1352540                     Sentience  Mar 25, 2021            0    0.0
# 415390   Viking Saga: The Cursed Ring  Oct 29, 2015            0   2.99
# 1043890                 Tipping Point  Apr 11, 2019            0   3.99
# ...                               ...           ...          ...    ...
# 1571000            Alphadia Genesis 2   Jun 3, 2021            0  14.99
# 513310                       Aviators  Jan 19, 2017            0   2.99
# 576160               A Long Road Home  Jan 31, 2017            0   1.99
# 1173830          Coloring Game: Pixel  Oct 25, 2019            0   1.99
# 445020               Frozen Synapse 2  Sep 13, 2018            0  29.99
#
#         dlc_count                               detailed_description  \
# ...

# %%
df_games.T.to_excel('dados.xlsx')
# Out:
# C:\Users\danie\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:1177: UserWarning: Ignoring URL 'http://dyscourse.com' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# C:\Users\danie\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:1177: UserWarning: Ignoring URL 'http://rogalia.ru' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# C:\Users\danie\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:1177: UserWarning: Ignoring URL 'http://choplifterhd.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# C:\Users\danie\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:1177: UserWarning: Ignoring URL 'http://www.youarenotthehero.com' since it exceeds Excel's limit of 65,530 URLS per worksheet.
# ...

# %%
df_games.shape
# Out:
# (41, 53436)

# %%
df_games.count(axis='columns')
# Out:
# name                        53436
# release_date                53436
# required_age                53436
# price                       53436
# dlc_count                   53436
# detailed_description        53436
# about_the_game              53436
# short_description           53436
# reviews                     53436
# header_image                53436
# website                     53436
# support_url                 53436
# support_email               53436
# windows                     53436
# mac                         53436
# linux                       53436
# metacritic_score            53436
# metacritic_url              53436
# achievements                53436
# recommendations             53436
# notes                       53436
# supported_languages         53436
# full_audio_languages        53436
# packages                    53436
# developers                  53436
# publishers                  53436
# categories                  53436
# ...

# %%
isnull = df_games.isnull().sum()

# %%
isnull
# Out:
# 606850     0
# 1787030    0
# 1352540    0
# 415390     0
# 1043890    0
#           ..
# 1571000    0
# 513310     0
# 576160     0
# 1173830    0
# 445020     0
# Length: 53436, dtype: int64

# %%
#df_mask = df_games['tags'] 'Indie'
#filtered_df = df_games[df_mask]
#print(filtered_df)
# Out:
#   File "C:\Users\danie\AppData\Local\Temp/ipykernel_4228/554142187.py", line 1
#     df_mask = df_games['tags'] 'Indie'
#                                ^
# SyntaxError: invalid syntax

# %%
#print(df_games['tags']=='RPG')

# %%
#df_games.to_json('./export.json', orient='columns')
